# %%
import csv
import pandas as pd
import pickle 
import os
# !pip install openpyxl
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
import os
print(os.listdir())
# Out:
# ['carte_zones_mediterranee.html', 'anomalies_rejets_plastique.csv', 'Rejets_de_plastiques_de_1990_2019.ipynb', 'projet_pollution_plastic_Tarek.ipynb', 'Data', 'croissance_annuelle_par_zone.png', 'src']

# %%
df = pd.read_excel('Data/Rejets_de_plastiques_de_1990_2019.xlsx')

df.head()
# Out:
#   STRUCTURE                    STRUCTURE_ID  \
# 0  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 1  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 2  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 3  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 4  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
#
#                         STRUCTURE_NAME ACTION REF_AREA Zone de référence  \
# 0  Rejets de plastiques de 1990 à 2019      I      F_O     Autre Afrique
# 1  Rejets de plastiques de 1990 à 2019      I      F_O     Autre Afrique
# 2  Rejets de plastiques de 1990 à 2019      I      F_O     Autre Afrique
# 3  Rejets de plastiques de 1990 à 2019      I      F_O     Autre Afrique
# 4  Rejets de plastiques de 1990 à 2019      I      F_O     Autre Afrique
#
#    MEASURE                                             Mesure  \
# 0  PL_AQ_O  Rejets de plastiques dans les environnements a...
# 1  PL_AQ_O  Rejets de plastiques dans les environnements a...
# 2  PL_AQ_O  Rejets de plastiques dans les environnements a...
# ...

# %%
import pandas as pd
import os

filepath = os.path.join('Data', 'Rejets_de_plastiques_de_1990_2019.xlsx')
df = pd.read_excel(filepath)
df.head()
# Out:
#   STRUCTURE                    STRUCTURE_ID  \
# 0  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 1  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 2  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 3  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 4  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
#
#                         STRUCTURE_NAME ACTION REF_AREA Zone de référence  \
# 0  Rejets de plastiques de 1990 à 2019      I      F_O     Autre Afrique
# 1  Rejets de plastiques de 1990 à 2019      I      F_O     Autre Afrique
# 2  Rejets de plastiques de 1990 à 2019      I      F_O     Autre Afrique
# 3  Rejets de plastiques de 1990 à 2019      I      F_O     Autre Afrique
# 4  Rejets de plastiques de 1990 à 2019      I      F_O     Autre Afrique
#
#    MEASURE                                             Mesure  \
# 0  PL_AQ_O  Rejets de plastiques dans les environnements a...
# 1  PL_AQ_O  Rejets de plastiques dans les environnements a...
# 2  PL_AQ_O  Rejets de plastiques dans les environnements a...
# ...

# %%
def load_file(filepath, sep=';'):
    with open(filepath) as f:
        reader = csv.DictReader(f, delimiter=sep)
        data = list(reader)
    
    return data

# %%
# Suppression de 2016 pour la zone problématique
zone_pb = "Membres de l'Union européenne et de l'OCDE"
df_clean = df[~((df['TIME_PERIOD'] == 2016) & (df['Zone de référence'] == zone_pb))]

# %%
# Interpolation linéaire sur la série temporelle
df_med_interp = df_med.copy()
df_med_interp['OBS_VALUE'] = df_med_interp.groupby('Zone de référence')['OBS_VALUE'].apply(lambda x: x.interpolate())

# %%
df.shape,df.shape[0]
# Out:
# ((1650, 26), 1650)

# %%
print(df.columns)
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'REF_AREA',
#        'Zone de référence', 'MEASURE', 'Mesure', 'PLASTIC_WATER',
#        'Le plastique dans les environnements aquatiques', 'FREQ',
#        'Fréquence d'observation', 'MISMANAGED_LITTERED_PLASTIC',
#        'Plastique mal géré', 'TIME_PERIOD', 'Temps', 'OBS_VALUE',
#        'Valeur de l'observation', 'OBS_STATUS', 'Statut de l'observation',
#        'UNIT_MULT', 'Multiplicateur d'unité', 'UNIT_MEASURE',
#        'Unité de mesure', 'DECIMALS', 'Décimales'],
#       dtype='object')

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1650 entries, 0 to 1649
# Data columns (total 26 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   STRUCTURE                                        1650 non-null   object
#  1   STRUCTURE_ID                                     1650 non-null   object
#  2   STRUCTURE_NAME                                   1650 non-null   object
#  3   ACTION                                           1650 non-null   object
#  4   REF_AREA                                         1650 non-null   object
#  5   Zone de référence                                1650 non-null   object
#  6   MEASURE                                          1650 non-null   object
#  7   Mesure                                           1650 non-null   object
#  8   PLASTIC_WATER                                    1650 non-null   object
# ...

# %%
print(df.isnull().sum())
# Out:
# STRUCTURE                                             0
# STRUCTURE_ID                                          0
# STRUCTURE_NAME                                        0
# ACTION                                                0
# REF_AREA                                              0
# Zone de référence                                     0
# MEASURE                                               0
# Mesure                                                0
# PLASTIC_WATER                                         0
# Le plastique dans les environnements aquatiques       0
# FREQ                                                  0
# Fréquence d'observation                               0
# MISMANAGED_LITTERED_PLASTIC                           0
# Plastique mal géré                                    0
# TIME_PERIOD                                           0
# Temps                                              1650
# OBS_VALUE                                             0
# ...

# %%
print(df.head())
# Out:
#   STRUCTURE                    STRUCTURE_ID  \
# 0  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 1  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 2  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 3  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 4  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
#
#                         STRUCTURE_NAME ACTION REF_AREA Zone de référence  \
# 0  Rejets de plastiques de 1990 à 2019      I      F_O     Autre Afrique
# 1  Rejets de plastiques de 1990 à 2019      I      F_O     Autre Afrique
# 2  Rejets de plastiques de 1990 à 2019      I      F_O     Autre Afrique
# 3  Rejets de plastiques de 1990 à 2019      I      F_O     Autre Afrique
# 4  Rejets de plastiques de 1990 à 2019      I      F_O     Autre Afrique
#
#    MEASURE                                             Mesure  \
# 0  PL_AQ_O  Rejets de plastiques dans les environnements a...
# 1  PL_AQ_O  Rejets de plastiques dans les environnements a...
# 2  PL_AQ_O  Rejets de plastiques dans les environnements a...
# ...

# %%
pip install folium
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
print(df.columns)
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'REF_AREA',
#        'Zone de référence', 'MEASURE', 'Mesure', 'PLASTIC_WATER',
#        'Le plastique dans les environnements aquatiques', 'FREQ',
#        'Fréquence d'observation', 'MISMANAGED_LITTERED_PLASTIC',
#        'Plastique mal géré', 'TIME_PERIOD', 'Temps', 'OBS_VALUE',
#        'Valeur de l'observation', 'OBS_STATUS', 'Statut de l'observation',
#        'UNIT_MULT', 'Multiplicateur d'unité', 'UNIT_MEASURE',
#        'Unité de mesure', 'DECIMALS', 'Décimales'],
#       dtype='object')

# %%
print(df.columns)
print(df.head())
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'REF_AREA',
#        'Zone de référence', 'MEASURE', 'Mesure', 'PLASTIC_WATER',
#        'Le plastique dans les environnements aquatiques', 'FREQ',
#        'Fréquence d'observation', 'MISMANAGED_LITTERED_PLASTIC',
#        'Plastique mal géré', 'TIME_PERIOD', 'Temps', 'OBS_VALUE',
#        'Valeur de l'observation', 'OBS_STATUS', 'Statut de l'observation',
#        'UNIT_MULT', 'Multiplicateur d'unité', 'UNIT_MEASURE',
#        'Unité de mesure', 'DECIMALS', 'Décimales'],
#       dtype='object')
#   STRUCTURE                    STRUCTURE_ID  \
# 0  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 1  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 2  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 3  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 4  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
#
#                         STRUCTURE_NAME ACTION REF_AREA Zone de référence  \
# ...

# %%
df['Zone de référence'] = df['Zone de référence'].str.strip()

# %%
df = pd.read_excel(filepath, sheet_name=0)

# %%
print(df['Zone de référence'].unique())
print(df['Zone de référence'].value_counts())
print(df.head())
# Out:
# ['Autre Afrique' 'Autre OCDE Amérique' 'Autre Asie' 'Amérique latine'
#  'Canada' "Pays non-union européenne de l'OCDE Europe"
#  'Chine (République populaire de)' 'Inde' 'OCDE Asie'
#  "Pays de l'Union européenne non membres de l'OCDE"
#  'Australie et Nouvelle-Zélande' 'États-Unis' 'Autre Eurasie non-OCDE'
#  "Membres de l'Union européenne et de l'OCDE"
#  'Moyen-Orient et Afrique du Nord']
# Autre Afrique                                       110
# Autre OCDE Amérique                                 110
# Autre Asie                                          110
# Amérique latine                                     110
# Canada                                              110
# Pays non-union européenne de l'OCDE Europe          110
# Chine (République populaire de)                     110
# Inde                                                110
# OCDE Asie                                           110
# Pays de l'Union européenne non membres de l'OCDE    110
# ...

# %%
print(df.head(20))
# Out:
#    STRUCTURE                    STRUCTURE_ID  \
# 0   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 1   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 2   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 3   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 4   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 5   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 6   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 7   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 8   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 9   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 10  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 11  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 12  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 13  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 14  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 15  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 16  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 17  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 18  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 19  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
#
# ...

# %%
print(df['TIME_PERIOD'].unique())
# Out:
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
#  2014 2015 2016 2017 2018 2019 1990 1991 1992 1993 1994 1995 1996 1997
#  1998 1999]

# %%
print(df.columns)
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'REF_AREA',
#        'Zone de référence', 'MEASURE', 'Mesure', 'PLASTIC_WATER',
#        'Le plastique dans les environnements aquatiques', 'FREQ',
#        'Fréquence d'observation', 'MISMANAGED_LITTERED_PLASTIC',
#        'Plastique mal géré', 'TIME_PERIOD', 'Temps', 'OBS_VALUE',
#        'Valeur de l'observation', 'OBS_STATUS', 'Statut de l'observation',
#        'UNIT_MULT', 'Multiplicateur d'unité', 'UNIT_MEASURE',
#        'Unité de mesure', 'DECIMALS', 'Décimales'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
print(df['OBS_VALUE'].dtype)
print(df['OBS_VALUE'].head(10))
# Out:
# object
# 0    0.273318
# 1    0.293288
# 2    0.319636
# 3    0.345043
# 4    0.374465
# 5    0.399767
# 6    0.431887
# 7    0.466044
# 8    0.478299
# 9    0.503873
# Name: OBS_VALUE, dtype: object

# %%
df['OBS_VALUE'] = pd.to_numeric(df['OBS_VALUE'], errors='coerce')

# %%
pivot = df.pivot_table(index='TIME_PERIOD', columns='Zone de référence', values='OBS_VALUE', aggfunc='sum')
pivot.plot(figsize=(12,6))
plt.title("Évolution des rejets de plastique par zone")
plt.ylabel("Rejets (unité)")
plt.xlabel("Année")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
total_par_zone = df.groupby('Zone de référence')['OBS_VALUE'].sum().sort_values(ascending=False)
total_par_zone.plot(kind='bar')
plt.title("Rejets totaux de plastique par zone (1990-2019)")
plt.ylabel("Rejets cumulés")
plt.show()

# %%
total_par_annee = df.groupby('TIME_PERIOD')['OBS_VALUE'].sum()
total_par_annee.plot()
plt.title("Évolution globale des rejets de plastique")
plt.ylabel("Rejets annuels")
plt.xlabel("Année")
plt.show()

# %%
# Interpolation linéaire sur tout le DataFrame
df_interp = df.copy()
df_interp['OBS_VALUE'] = (
    df_interp
    .groupby('Zone de référence')['OBS_VALUE']
    .apply(lambda x: x.interpolate())
)

# Sélection uniquement des 3 zones méditerranéennes
zones_mediterranee = [
    "Moyen-Orient et Afrique du Nord",
    "Pays de l'Union européenne non membres de l'OCDE",
    "Membres de l'Union européenne et de l'OCDE",
]

df_med = df_interp[df_interp['Zone de référence'].isin(zones_mediterranee)]

total_par_annee_med = df_med.groupby('TIME_PERIOD')['OBS_VALUE'].sum()
total_par_annee_med.plot()
plt.title("Évolution des rejets de plastique des zones méditerranéennes")
plt.ylabel("Rejets annuels")
plt.xlabel("Année")
plt.show()

# %%
# Interpolation linéaire sur tout le DataFrame
df_interp = df.copy()
df_interp['OBS_VALUE'] = (
    df_interp
    .groupby('Zone de référence')['OBS_VALUE']
    .apply(lambda x: x.interpolate())
)

# Zones méditerranéennes
zones_mediterranee = [
    "Moyen-Orient et Afrique du Nord",
    "Pays de l'Union européenne non membres de l'OCDE",
    "Membres de l'Union européenne et de l'OCDE",
]

# Série globale
total_par_annee_global = df_interp.groupby('TIME_PERIOD')['OBS_VALUE'].sum()

# Série méditerranéenne
df_med = df_interp[df_interp['Zone de référence'].isin(zones_mediterranee)]
total_par_annee_med = df_med.groupby('TIME_PERIOD')['OBS_VALUE'].sum()

# Tracé comparatif
plt.figure(figsize=(10,6))
plt.plot(total_par_annee_global.index, total_par_annee_global.values, label="Global", color='grey')
plt.plot(total_par_annee_med.index, total_par_annee_med.values, label="Méditerranée", color='blue')
plt.title("Évolution des rejets de plastique : Global vs Méditerranée")
plt.ylabel("Rejets annuels")
plt.xlabel("Année")
plt.legend()
plt.show()

# %%
pivot = df.pivot_table(index='TIME_PERIOD', columns='Zone de référence', values='OBS_VALUE', aggfunc='sum')
pivot.plot(kind='bar', stacked=True, figsize=(14,7))
plt.title("Répartition annuelle des rejets de plastique par zone")
plt.ylabel("Rejets")
plt.xlabel("Année")
plt.show()

# %%
croissance = (
    df.groupby('Zone de référence')
      .apply(lambda g: (g.sort_values('TIME_PERIOD')['OBS_VALUE'].iloc[-1] - g.sort_values('TIME_PERIOD')['OBS_VALUE'].iloc[0]) / (g['TIME_PERIOD'].nunique()-1))
      .sort_values(ascending=False)
)
print("Croissance annuelle moyenne par zone :")
print(croissance)
croissance.plot(kind='bar')
plt.title("Croissance annuelle moyenne des rejets par zone")
plt.ylabel("Croissance annuelle moyenne")
plt.show()
# Out:
# Croissance annuelle moyenne par zone :
# Zone de référence
# Membres de l'Union européenne et de l'OCDE          0.379637
# Autre Eurasie non-OCDE                              0.301849
# Autre Asie                                          0.192628
# Chine (République populaire de)                     0.115000
# Autre Afrique                                       0.096828
# États-Unis                                          0.092280
# Inde                                                0.061207
# Canada                                              0.012042
# Autre OCDE Amérique                                 0.011069
# Moyen-Orient et Afrique du Nord                     0.001660
# Pays de l'Union européenne non membres de l'OCDE    0.001103
# Australie et Nouvelle-Zélande                       0.000828
# OCDE Asie                                          -0.002861
# Amérique latine                                    -0.004578
# ...

# %%
# On considère comme anomalie toute valeur au-dessus du 99e percentile ou en-dessous du 1er percentile
q_low = df['OBS_VALUE'].quantile(0.01)
q_high = df['OBS_VALUE'].quantile(0.99)
anomalies = df[(df['OBS_VALUE'] < q_low) | (df['OBS_VALUE'] > q_high)]
print("Anomalies détectées :")
print(anomalies[['TIME_PERIOD', 'Zone de référence', 'OBS_VALUE']])
# Out:
# Anomalies détectées :
#       TIME_PERIOD                                 Zone de référence  OBS_VALUE
# 666          2006                   Chine (République populaire de)  11.825540
# 667          2007                   Chine (République populaire de)  12.865360
# 668          2008                   Chine (République populaire de)  13.904850
# 669          2009                   Chine (République populaire de)  14.970830
# 670          2010                   Chine (République populaire de)  16.095290
# 671          2011                   Chine (République populaire de)  17.254240
# 672          2012                   Chine (République populaire de)  18.428210
# 673          2013                   Chine (République populaire de)  19.606510
# 674          2014                   Chine (République populaire de)  20.802120
# 675          2015                   Chine (République populaire de)  21.990220
# 676          2016                   Chine (République populaire de)  23.155390
# ...

# %%
# Export des anomalies en CSV
anomalies.to_csv("anomalies_rejets_plastique.csv", index=False)

# Export du graphique de croissance
fig = plt.figure()
croissance.plot(kind='bar')
plt.title("Croissance annuelle moyenne des rejets par zone")
plt.ylabel("Croissance annuelle moyenne")
plt.savefig("croissance_annuelle_par_zone.png")
plt.close(fig)
print(anomalies)
# Out:
#      STRUCTURE                    STRUCTURE_ID  \
# 666   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 667   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 668   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 669   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 670   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 671   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 672   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 673   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 674   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 675   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 676   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 677   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 678   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 679   DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 1347  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 1348  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 1349  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 1350  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# 1351  DATAFLOW  OECD.ENV.EEI:DSD_PL@DF_PL(1.0)
# ...

# %%
variation_totale = (
    df.sort_values('TIME_PERIOD')
      .groupby('Zone de référence')['OBS_VALUE']
      .agg(lambda x: x.iloc[-1] - x.iloc[0])
      .sort_values(ascending=False)
)
variation_totale.plot(kind='bar')
plt.title("Variation totale des rejets par zone (fin - début)")
plt.ylabel("Variation totale")
plt.show()

# %%
variabilite = df.groupby('Zone de référence')['OBS_VALUE'].std().sort_values(ascending=False)

plt.figure(figsize=(8,5))
ax = variabilite.plot(kind='bar', width=0.7)
ax.set_xticklabels(variabilite.index, rotation=20, ha='right', fontsize=10)
plt.title("Variabilité annuelle des rejets par zone (écart-type)")
plt.ylabel("Écart-type annuel")
plt.xlabel("Zone de référence")

# Ajout des valeurs sur chaque barre
for p in ax.patches:
    ax.annotate(f"{p.get_height():.1f}", 
                (p.get_x() + p.get_width() / 2, p.get_height()), 
                ha='center', va='bottom', fontsize=9, color='black', rotation=0)

plt.tight_layout()
plt.show()

# %%
annee = 2019  # à adapter
part_annee = df[df['TIME_PERIOD'] == annee].groupby('Zone de référence')['OBS_VALUE'].sum()
part_annee.plot(kind='pie', autopct='%1.1f%%', figsize=(8,8))
plt.title(f"Part des rejets par zone en {annee}")
plt.ylabel("")
plt.show()

# %%
# Liste des zones méditerranéennes à adapter selon tes données
zones_mediterranee = [
    "Moyen-Orient et Afrique du Nord",
    "Pays de l'Union européenne non membres de l'OCDE",
    "Membres de l'Union européenne et de l'OCDE",
    # Ajoute ici d'autres pays/zones méditerranéennes si besoin
]

annee = 2019  # à adapter
df_med = df[(df['TIME_PERIOD'] == annee) & (df['Zone de référence'].isin(zones_mediterranee))]
part_med = df_med.groupby('Zone de référence')['OBS_VALUE'].sum()
part_med.plot(kind='pie', autopct='%1.1f%%', figsize=(8,8))
plt.title(f"Part des rejets par zone méditerranéenne en {annee}")
plt.ylabel("")
plt.show()

# %%
# Liste des zones méditerranéennes à adapter selon tes données
zones_mediterranee = [
    "Moyen-Orient et Afrique du Nord",
    "Pays de l'Union européenne non membres de l'OCDE",
    "Membres de l'Union européenne et de l'OCDE",
    # Ajoute ici d'autres pays/zones méditerranéennes si besoin
]

annee = 1990  # à adapter
df_med = df[(df['TIME_PERIOD'] == annee) & (df['Zone de référence'].isin(zones_mediterranee))]
part_med = df_med.groupby('Zone de référence')['OBS_VALUE'].sum()
part_med.plot(kind='pie', autopct='%1.1f%%', figsize=(8,8))
plt.title(f"Part des rejets par zone méditerranéenne en {annee}")
plt.ylabel("")
plt.show()

# %%
zones_mediterranee = [
    "Moyen-Orient et Afrique du Nord",
    "Pays de l'Union européenne non membres de l'OCDE",
    "Membres de l'Union européenne et de l'OCDE",
    # d'autres pays/zones méditerranéennes si besoin
]

# Filtrer les données pour les zones méditerranéennes
df_med = df[df['Zone de référence'].isin(zones_mediterranee)].copy()

# Interpolation linéaire sur la série temporelle pour chaque zone
df_med['OBS_VALUE'] = df_med.groupby('Zone de référence')['OBS_VALUE'].apply(lambda x: x.interpolate())

# Pivot et tracé
pivot_med_interp = df_med.pivot_table(index='TIME_PERIOD', columns='Zone de référence', values='OBS_VALUE', aggfunc='sum')
pivot_med_interp.plot(figsize=(12,6))
plt.title("Évolution des rejets de plastique des zones méditerranéennes (1990-2019) - Valeurs interpolées")
plt.ylabel("Rejets (unité)")
plt.xlabel("Année")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
# Interpolation linéaire sur la période 2009-2019 pour chaque zone méditerranéenne
df_med_2009_2019 = df[
    (df['TIME_PERIOD'] >= 2009) &
    (df['TIME_PERIOD'] <= 2019) &
    (df['Zone de référence'].isin(zones_mediterranee))
].copy()

df_med_2009_2019['OBS_VALUE'] = (
    df_med_2009_2019
    .groupby('Zone de référence')['OBS_VALUE']
    .apply(lambda x: x.interpolate())
)

pivot_med = df_med_2009_2019.pivot_table(
    index='TIME_PERIOD',
    columns='Zone de référence',
    values='OBS_VALUE',
    aggfunc='sum'
)

pivot_med.plot(kind='bar', stacked=True, figsize=(14,7))
plt.title("Répartition annuelle des rejets de plastique par zone méditerranéenne (2009-2019) - Valeurs interpolées")
plt.ylabel("Rejets")
plt.xlabel("Année")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

def split_label(label):
    words = label.split()
    return '\n'.join([' '.join(words[i:i+2]) for i in range(0, len(words), 2)])

rejets_zones = df_med_2009_2019.groupby('Zone de référence')['OBS_VALUE'].sum().sort_values(ascending=False)
labels = [split_label(l) for l in rejets_zones.index]

plt.figure(figsize=(8,5))
ax = rejets_zones.plot(kind='bar', color=['red', 'orange', 'green'])
ax.set_xticklabels(labels, rotation=0, ha='center', fontsize=10)
plt.title("Rejets cumulés de plastique par zone méditerranéenne (2009-2019)")
plt.ylabel("Rejets cumulés")
plt.xlabel("Zone de référence")
plt.tight_layout()
plt.show()

# %%
import folium

# Coordonnées littorales pour chaque zone
zone_coords = {
    "Moyen-Orient et Afrique du Nord": [36.8, 10.2],   # Tunis, Tunisie (côte nord-africaine)
    "Pays de l'Union européenne non membres de l'OCDE": [42.7, 18.1],  # Dubrovnik, Croatie (côte adriatique)
    "Membres de l'Union européenne et de l'OCDE": [43.3, 5.4],   # Marseille, France (côte nord méditerranéenne)
}

# Somme des rejets par zone sur 2009-2019
rejets_zones = df_med_2009_2019.groupby('Zone de référence')['OBS_VALUE'].sum()

# Création de la carte centrée sur la Méditerranée
m = folium.Map(location=[38, 15], zoom_start=5)

for zone, coords in zone_coords.items():
    valeur = rejets_zones.get(zone, 0)
    folium.CircleMarker(
        location=coords,
        radius=10 + valeur/1e6,  # Ajuste le facteur selon l'échelle de tes données
        popup=f"{zone}: {valeur:.0f}",
        color='blue',
        fill=True,
        fill_color='blue'
    ).add_to(m)

m.save("carte_zones_mediterranee.html")
m  # Affiche dans le notebook si supporté
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
