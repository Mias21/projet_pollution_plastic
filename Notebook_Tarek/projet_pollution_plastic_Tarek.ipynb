# %%
import csv
import pickle 
import os

# %%
filepath = os.path.join('Data','ocean_plastic_pollution_data.csv')

with open(filepath) as f:
    reader = csv.DictReader(f, delimiter=';')
    data = list(reader)
    
data
# Out:
# [{'Date,Region,Latitude,Longitude,Plastic_Type,Plastic_Weight_kg,Depth_meters': '01/01/2015 0:00,Arctic Ocean,-58.45962737,-169.6264556,Polyethylene Terephthalate (PET),41.93,73.09'},
#  {'Date,Region,Latitude,Longitude,Plastic_Type,Plastic_Weight_kg,Depth_meters': '01/01/2015 1:00,Southern Ocean,49.44989207,77.31985156,Polyethylene (PE),403.38,71.21'},
#  {'Date,Region,Latitude,Longitude,Plastic_Type,Plastic_Weight_kg,Depth_meters': '01/01/2015 2:00,Indian Ocean,80.42241101,130.332581,Polyethylene Terephthalate (PET),241.7,19.53'},
#  {'Date,Region,Latitude,Longitude,Plastic_Type,Plastic_Weight_kg,Depth_meters': '01/01/2015 3:00,Southern Ocean,-71.92072478,58.00356276,Polyethylene Terephthalate (PET),482.76,69.72'},
#  {'Date,Region,Latitude,Longitude,Plastic_Type,Plastic_Weight_kg,Depth_meters': '01/01/2015 4:00,Southern Ocean,-61.99374161,-169.0112823,Polyethylene Terephthalate (PET),58.75,58.14'},
# ...

# %%
def load_file(filepath, sep=';'):
    with open(filepath) as f:
        reader = csv.DictReader(f, delimiter=sep)
        data = list(reader)
    
    return data

# %%
filepath = os.path.join('Data','ocean_plastic_pollution_data.csv')
data = load_file(filepath)
data
# Out:
# [{'Date,Region,Latitude,Longitude,Plastic_Type,Plastic_Weight_kg,Depth_meters': '01/01/2015 0:00,Arctic Ocean,-58.45962737,-169.6264556,Polyethylene Terephthalate (PET),41.93,73.09'},
#  {'Date,Region,Latitude,Longitude,Plastic_Type,Plastic_Weight_kg,Depth_meters': '01/01/2015 1:00,Southern Ocean,49.44989207,77.31985156,Polyethylene (PE),403.38,71.21'},
#  {'Date,Region,Latitude,Longitude,Plastic_Type,Plastic_Weight_kg,Depth_meters': '01/01/2015 2:00,Indian Ocean,80.42241101,130.332581,Polyethylene Terephthalate (PET),241.7,19.53'},
#  {'Date,Region,Latitude,Longitude,Plastic_Type,Plastic_Weight_kg,Depth_meters': '01/01/2015 3:00,Southern Ocean,-71.92072478,58.00356276,Polyethylene Terephthalate (PET),482.76,69.72'},
#  {'Date,Region,Latitude,Longitude,Plastic_Type,Plastic_Weight_kg,Depth_meters': '01/01/2015 4:00,Southern Ocean,-61.99374161,-169.0112823,Polyethylene Terephthalate (PET),58.75,58.14'},
# ...

# %%
len(data)
# Out:
# 15000

# %%
import pandas as pd

filepath = os.path.join('Data', 'ocean_plastic_pollution_data.csv')
data = pd.read_csv(filepath)  
data.head()
# Out:
#               Date          Region   Latitude   Longitude  \
# 0  01/01/2015 0:00    Arctic Ocean -58.459627 -169.626456
# 1  01/01/2015 1:00  Southern Ocean  49.449892   77.319852
# 2  01/01/2015 2:00    Indian Ocean  80.422411  130.332581
# 3  01/01/2015 3:00  Southern Ocean -71.920725   58.003563
# 4  01/01/2015 4:00  Southern Ocean -61.993742 -169.011282
#
#                        Plastic_Type  Plastic_Weight_kg  Depth_meters
# 0  Polyethylene Terephthalate (PET)              41.93         73.09
# 1                 Polyethylene (PE)             403.38         71.21
# 2  Polyethylene Terephthalate (PET)             241.70         19.53
# 3  Polyethylene Terephthalate (PET)             482.76         69.72
# 4  Polyethylene Terephthalate (PET)              58.75         58.14

# %%
print(data.columns)
# Out:
# Index(['Date', 'Region', 'Latitude', 'Longitude', 'Plastic_Type',
#        'Plastic_Weight_kg', 'Depth_meters'],
#       dtype='object')
